# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # Challenge Chemoocs-chapitre 1 non supervisé saison 7 2022-2023
#
# ## Présentation
#
# Les données de départ sont constituées d’une collection de spectres proche infrarouge acquis en réflectance sur 8 différents types de produits agroalimentaires (blé, maïs, colza, …). Environ 40 spectres de chaque groupe sont rassemblés pour former une matrice de 327 spectres pour 680 variables (longueurs d’onde).
# Le but du challenge est de rassembler les spectres en 8 classes correspondant aux 8 types de produits. Il n’est bien sûr pas question d’identifier les types de produits (blé, maïs,…) mais seulement de rassembler les échantillons par leur proximité spectrale.
#
# ## Les données
#
# Le fichier est un CSV, séparateur de champ = virgule "," /  séparateur décimal = point "."
#
# Il est à télécharger ici -> Données challenge non supervisé 2022 ( https://lms.fun-mooc.fr/asset-v1:Agreenium+66002+session08+type@asset+block/Challenge_2022_X.csv)
#
# ## Réalisation du challenge
#
# Vous pouvez utiliser des méthodes d’exploration (analyse en composante principale), des méthodes de classification non-supervisée, et des prétraitements.
# Pour vous aider dans le réalisation de ce challenge, nous vous proposons 2 indices :
# 1- Les spectres 132 et 216 ne sont pas dans la même classe.
#
# 2- Les spectres 75 et 287 ne sont pas dans la même classe.
# A l'issue de ce travail, vous aurez déterminé 8 groupes d'observations.
#
# Chacun de ces 8 groupes sera associé avec un des numéros 1 à 8.
#
# Ne vous inquiétez-pas de l'ordre des numéros. Si deux groupes sont permutés, p.ex. le groupe 3 devient le 7 et le groupe 7 devient le 3, aucun problème!

# %%
# Import des différentes biblothèques
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# # EDA Exploratory Data Analysis

# %% [markdown]
# ## Visualisation des spectres et corrections

# %%
df = pd.read_csv("data/Challenge_2022_X.csv")
df.head()
spectres = df.drop(' ',axis=1)
spectres = spectres.values

x = df.drop(' ',axis=1)
x = x.columns
for i in range(len(spectres)):
    plt.plot(x,spectres[i])

# %% [markdown]
# Remarque :
# - on observe qu'il y a des effets multiplicatif pkus on approche de zéro plus les valeurs différences baissent.
#     on fera une représentation en spectres = f(spectres moyen)

# %%
x
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
#        ...
#        'X671', 'X672', 'X673', 'X674', 'X675', 'X676', 'X677', 'X678', 'X679',
#        'X680'],
#       dtype='object', length=680)

# %%
df.columns
# Out:
# Index([' ', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        ...
#        'X671', 'X672', 'X673', 'X674', 'X675', 'X676', 'X677', 'X678', 'X679',
#        'X680'],
#       dtype='object', length=681)

# %%
df.columns
# Out:
# Index(['\', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        ...
#        'X671', 'X672', 'X673', 'X674', 'X675', 'X676', 'X677', 'X678', 'X679',
#        'X680'],
#       dtype='object', length=681)
